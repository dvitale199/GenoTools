# %%
import pandas as pd
import glob
import numpy as np
import os
import shutil

# %%
gd_path = '/data/CARD/PD/GP2/raw_genotypes/GD'
idat_path = f'{gd_path}/idats'
swarm_scripts_dir = f'{gd_path}/swarm_scripts'
raw_plink_path = f'{gd_path}/plink'
gd_qc_path = f'{gd_path}/QC'

ilmn_files_path = '/data/CARD/PD/GP2/ilmn_files'
bpm = f'{ilmn_files_path}/NeuroBooster_20042459_A1.bpm'
egt = f'{ilmn_files_path}/NBSCluster_file_n1393_011921.egt'
iaap = f'{ilmn_files_path}/iaap-cli/iaap-cli'

clin_dir = '/data/CARD/PD/GP2/clinical'
key_dir = '/data/CARD/PD/GP2/key_files'
gd_key = f'{key_dir}/gd_key.csv'

# %%
nhgri_clin = pd.read_csv(f'{clin_dir}/sample_sheet_nhgri.csv')
ny_clin = pd.read_csv(f'{clin_dir}/sample_sheet_newyork.csv')
key = pd.read_csv(gd_key)
key['filename'] = key['SentrixBarcode_A'].astype(str) + '_' + key['SentrixPosition_A']

key.loc[:,'FID'] = '0'

key[['FID', 'filename', 'FID', 'Sample_ID']].to_csv(f'{gd_path}/update_ids.txt', sep='\t', header=None, index=None)

# %%
with open(f'{swarm_scripts_dir}/idat_to_ped.swarm', 'w') as f:
    
    for code in key.SentrixBarcode_A.unique():
        
        idat_to_ped_cmd = f'\
{iaap} gencall \
{bpm} \
{egt} \
{raw_plink_path}/ \
-f {idat_path}/{code} \
-p \
-t 8'
        
        f.write(f'{idat_to_ped_cmd}\n')
f.close()

# %%
# !swarm -f {swarm_scripts_dir}/idat_to_ped.swarm -g 32 -t 16 --time=10:00:00 --logdir {swarm_scripts_dir}/logs --gres=lscratch:20 --partition=norm
# Out:
# 21031358

# %%
# copy map file to match name of each ped
map_file = f'{raw_plink_path}/NeuroBooster_20042459_A1.map'
for filename in key.filename:
    ped = f'{raw_plink_path}/{filename}.ped'
    out_map = f'{raw_plink_path}/{filename}.map'
    if os.path.isfile(ped):
        shutil.copyfile(src=map_file, dst=out_map)
    else:
        print(f'{ped} does not exist!')
        print(f'{out_map} creation cancelled')

# %%
with open(f'{swarm_scripts_dir}/make_bed.swarm', 'w') as f:
    for filename in key.filename:
        ped = f'{raw_plink_path}/{filename}'
        make_bed_cmd = f'\
plink \
--file {ped} \
--make-bed \
--out {raw_plink_path}/{filename}'

        f.write(f'{make_bed_cmd}\n')
f.close()

# %%
# !swarm -f {swarm_scripts_dir}/make_bed.swarm -g 64 -t 32 --time=10:00:00 --logdir swarm --gres=lscratch:20 --partition=norm
# Out:
# 21031946

# %%
# write plink merge command
with open(f"{raw_plink_path}/merge_bed.list", 'w') as f:
    for filename in key.filename:
        bed = f'{raw_plink_path}/{filename}'
        if os.path.isfile(f'{bed}.bed'):
            f.write(f'{bed}\n')
        else:
            print(f'{bed} does not exist!!!')
f.close()

with open(f"{swarm_scripts_dir}/merge.swarm", 'w') as f:

    plink_merge_cmd = f'\
plink \
--merge-list {raw_plink_path}/merge_bed.list \
--update-ids {gd_path}/update_ids.txt \
--make-bed \
--out {gd_qc_path}/GD'
    f.write(f"{plink_merge_cmd}")
f.close()

# %%
# !swarm -f {swarm_scripts_dir}/merge.swarm -g 64 -t 32 --time=10:00:00 --logdir swarm --gres=lscratch:20 --partition=norm
# Out:
# 21034777

# %%
# !ls /data/CARD/PD/GP2/genotypes/GD/clean
# Out:
# GD_AAC.bed  GD_AJ.bed  GD_AMR.bed  GD_EAS.bed  GD_EUR.bed  GD.QC.metrics.h5
# GD_AAC.bim  GD_AJ.bim  GD_AMR.bim  GD_EAS.bim  GD_EUR.bim
# GD_AAC.fam  GD_AJ.fam  GD_AMR.fam  GD_EAS.fam  GD_EUR.fam
# GD_AAC.hh   GD_AJ.hh   GD_AMR.hh   GD_EAS.hh   GD_EUR.hh
# GD_AAC.log  GD_AJ.log  GD_AMR.log  GD_EAS.log  GD_EUR.log

# %%
geno_path = f'{gd_qc_path}/GD'
ref_dir_path = '/data/LNG/vitaled2/1kgenomes'
ref_panel = f'{ref_dir_path}/1kg_ashkj_ref_panel_gp2_pruned'
ref_labels = f'{ref_dir_path}/ref_panel_ancestry.txt'
out_dir = '/data/CARD/PD/GP2/genotypes/GD/clean'
out_path = f'{out_dir}/GD'

# %%
with open(f'{swarm_scripts_dir}/run_qc_pipeline.swarm','w') as f:
    run_pipeline = f'python3 run_gd_pipeline.py --geno {geno_path} --ref {ref_panel} --ref_labels {ref_labels} --out {out_path}'
    f.write(f'{run_pipeline}\n')
f.close()
# !cat {swarm_scripts_dir}/run_qc_pipeline.swarm
# Out:
# python3 run_gd_pipeline.py --geno /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD --ref /data/LNG/vitaled2/1kgenomes/1kg_ashkj_ref_panel_gp2_pruned --ref_labels /data/LNG/vitaled2/1kgenomes/ref_panel_ancestry.txt --out /data/CARD/PD/GP2/genotypes/GD/clean/GD

# %%
# !swarm -f {swarm_scripts_dir}/run_qc_pipeline.swarm -g 64 -t 32 --time=10:00:00 --logdir {swarm_scripts_dir}/logs --gres=lscratch:20 --partition=norm
# Out:
# 21381364

# %%
from QC.imputation import *
import QC.config as config
# from QC.imputation import impute_data_prep
# these files need to be in a different place eventually
ref_panel='/data/vitaled2/GenoTools/ref/PASS.Variantsbravo-dbsnp-all.tab'
check_bim_pl = '/data/vitaled2/GenoTools/ref/HRC-1000G-check-bim.pl'

imputed_out_dir = '/data/CARD/PD/GP2/genotypes/GD/imputed' 
os.makedirs(imputed_out_dir, exist_ok=True)

# jenky method for pulling cleaned genos with ancestry labels for imputation... should figure out how to do this better later
impute_genos_list = [x.split('.')[0] for x in glob.glob(f'{out_dir}/*.bed')]

impute_labels_list = [x.split('/')[-1].replace('.bed','').split('_')[-1] for x in impute_genos_list]

for geno, label in zip(impute_genos_list, impute_labels_list):
    label_outdir = f'{imputed_out_dir}/{label}'
    impute_prep_outdir = f'{gd_path}/QC/{label}'
    impute_prep_geno = f'{impute_prep_outdir}/{label}'

    os.makedirs(f'{label_outdir}', exist_ok=True)
    os.makedirs(f'{impute_prep_outdir}', exist_ok=True)
    print(label_outdir)
#     impute_data = impute_data_prep(geno, impute_prep_geno, ref_panel, check_bim_pl)
    
#     run_pipeline = f'python3 ../run_imputation_pipeline.py --geno {geno} --temp {label_temp} --token {config.api_key} --ref_panel {ref_panel} --check_bim_pl {check_bim_pl} --out {label_outdir}/'
# Out:
# /data/CARD/PD/GP2/genotypes/GD/imputed/AAC
# /data/CARD/PD/GP2/genotypes/GD/imputed/EUR
# /data/CARD/PD/GP2/genotypes/GD/imputed/AJ
# /data/CARD/PD/GP2/genotypes/GD/imputed/AMR
# /data/CARD/PD/GP2/genotypes/GD/imputed/EAS

# %%
# !cat /data/CARD/PD/GP2/raw_genotypes/GD/QC/AAC/GD_AAC.fam | wc -l
# Out:
# 9

# %%
# now make list of vcfs and submit job
job_id_df = pd.DataFrame()

token = config.api_key
password = 'imputer'

for geno, label in zip(impute_genos_list[3:], impute_labels_list[3:]):
    label_outdir = f'{imputed_out_dir}/{label}'
    impute_prep_outdir = f'{gd_path}/QC/{label}'
    impute_prep_geno = f'{impute_prep_outdir}/{label}'
    print(impute_prep_geno)
    vcf_list = [f'{impute_prep_geno}_pre_impute_chr{str(i)}.vcf.gz' for i in range(1,24)]

    
    job_json = submit_job(vcf_list, password=password, token=token)
    
    job_id = job_json['id']
    
    job_id_df_tmp = pd.DataFrame({'job_id': [job_id], 'label': [label], 'path': [geno]})
    job_id_df = job_id_df.append(job_id_df_tmp)

job_id_df.to_csv(f'{imputed_out_dir}/impute_job_ids.csv')
# Out:
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/AMR/AMR
# job-20210830-160043-679 Your job was successfully added to the job queue.
# ***************************
# * * * * * * * * * * * * * *
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/EAS/EAS
# job-20210830-160045-801 Your job was successfully added to the job queue.
# ***************************
# * * * * * * * * * * * * * *

# %%
# now, merge EUR and AJ and impute together
# !mkdir /data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ
eur_path = '/data/CARD/PD/GP2/genotypes/GD/clean/GD_EUR'
aj_path = '/data/CARD/PD/GP2/genotypes/GD/clean/GD_AJ'
eur_aj_path = '/data/CARD/PD/GP2/genotypes/GD/clean/GD_EUR_AJ'

plink_merge_cmd = f'\
plink \
--bfile {eur_path} \
--bmerge {aj_path} \
--make-bed \
--out {eur_aj_path}'

shell_do(plink_merge_cmd)
# Out:
# Executing: plink --bfile /data/CARD/PD/GP2/genotypes/GD/clean/GD_EUR --bmerge /data/CARD/PD/GP2/genotypes/GD/clean/GD_AJ --make-bed --out /data/CARD/PD/GP2/genotypes/GD/clean/GD_EUR_AJ

# %%
from QC.imputation import *
import QC.config as config
# from QC.imputation import impute_data_prep
# these files need to be in a different place eventually
ref_panel='/data/vitaled2/GenoTools/ref/PASS.Variantsbravo-dbsnp-all.tab'
check_bim_pl = '/data/vitaled2/GenoTools/ref/HRC-1000G-check-bim.pl'

imputed_out_dir = '/data/CARD/PD/GP2/genotypes/GD/imputed' 

geno = eur_aj_path
label = 'EUR_AJ'

label_outdir = f'{imputed_out_dir}/{label}'
impute_prep_outdir = f'{gd_path}/QC/{label}'
impute_prep_geno = f'{impute_prep_outdir}/{label}'

os.makedirs(f'{label_outdir}', exist_ok=True)
os.makedirs(f'{impute_prep_outdir}', exist_ok=True)
print(label_outdir)
impute_data = impute_data_prep(geno, impute_prep_geno, ref_panel, check_bim_pl)
# Out:
# /data/CARD/PD/GP2/genotypes/GD/imputed/EUR_AJ
# Executing: plink --bfile GD_EUR_AJ --freq --out EUR_AJ
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging
200000 25300000 25400000 25500000 25600000 25700000 25800000 25900000 26000000 26100000 26200000 26300000 26400000 26500000 26600000 26700000 26800000 26900000 27000000 27100000 27200000 27300000 27400000 27500000 27600000 27700000 27800000 27900000 28000000 28100000 28200000 28300000 28400000 28500000 28600000 28700000 28800000 28900000 29000000 29100000 29200000 29300000 29400000 29500000 29600000 29700000 29800000 29900000 30000000 30100000 30200000 30300000 30400000 30500000 30600000 30700000 30800000 30900000 31000000 31100000 31200000 31300000 31400000 31500000 31600000 31700000 31800000 31900000 32000000 32100000 32200000 32300000 32400000 32500000 32600000 32700000 32800000 32900000 33000000 33100000 33200000 33300000 33400000 33500000 33600000 33700000 33800000 33900000 34000000 34100000 34200000 34300000 34400000 34500000 34600000 34700000 34800000 34900000 35000000 35100000 35200000 35300000 35400000 35500000 35600000 35700000 35800000 35900000 36000000 36100000 36200000 36300000 36400000 36500000 36600000 36700000 36800000 36900000 37000000 37100000 37200000 37300000 37400000 37500000 37600000 37700000 37800000 37900000 38000000 38100000 38200000 38300000 38400000 38500000 38600000 38700000 38800000 38900000 39000000 39100000 39200000 39300000 39400000 39500000 39600000 39700000 39800000 39900000 40000000 40100000 40200000 40300000 40400000 40500000 40600000 40700000 40800000 40900000 41000000 41100000 41200000 41300000 41400000 41500000 41600000 41700000 41800000 41900000 42000000 42100000 42200000 42300000 42400000 42500000 42600000 42700000 42800000 42900000 43000000 43100000 43200000 43300000 43400000 43500000 43600000 43700000 43800000 43900000 44000000 44100000 44200000 44300000 44400000 44500000 44600000 44700000 44800000 44900000 45000000 45100000 45200000 45300000 45400000 45500000 45600000 457 ...
# Matching to HRC
#
# Position Matches
#  ID matches HRC 755682
#  ID Doesn't match HRC 722419
#  Total Position Matches 1478101
# ID Match
#  Different position to HRC 157
# No Match to HRC 413956
# Skipped (X, XY, Y, MT) 13505
# Total in bim file 2004347
# Total processed 1905719
#
# Indels (ignored in r1) 45752
#
# SNPs not changed 142177
# SNPs to change ref alt 1073103
# Strand ok 705677
# Total Strand ok 1215280
#
# Strand to change 587089
# Total checked 1478258
# Total checked Strand 1292766
# Total removed for allele Frequency diff > 0.2 81611
# Palindromic SNPs with Freq > 0.4 7040
#
#
# Non Matching alleles 178452
# ID and allele mismatching 140059; where HRC is . 43000
# Duplicates removed 52876
# Executing: sh Run-plink.sh
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP1.log.
# Options in effect:
#   --bfile GD_EUR_AJ
#   --exclude Exclude-GD_EUR_AJ-HRC.txt
#   --make-bed
#   --out TEMP1
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 2004347 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# --exclude: 1211155 variants remaining.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996089.
# 1211155 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to TEMP1.bed + TEMP1.bim + TEMP1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP2.log.
# Options in effect:
#   --bfile TEMP1
#   --make-bed
#   --out TEMP2
#   --update-chr
#   --update-map Chromosome-GD_EUR_AJ-HRC.txt
#
# Note: --update-map [filename] + parameter-free --update-chr deprecated.  Use
# --update-chr [filename] instead.
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996089.
# 1211155 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --update-chr: 14 values updated, 143 variant IDs not present.
# --make-bed to TEMP2.bed + TEMP2.bim + TEMP2.fam ... .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP3.log.
# Options in effect:
#   --bfile TEMP2
#   --make-bed
#   --out TEMP3
#   --update-map Position-GD_EUR_AJ-HRC.txt
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# --update-map: 14 values updated, 143 variant IDs not present.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996089.
# 1211155 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to TEMP3.bed + TEMP3.bim + TEMP3.fam ... .
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to TEMP4.log.
# Options in effect:
#   --bfile TEMP3
#   --flip Strand-Flip-GD_EUR_AJ-HRC.txt
#   --make-bed
#   --out TEMP4
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# --flip: 578297 SNPs flipped, 8792 SNP IDs not present.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996089.
# 1211155 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to TEMP4.bed + TEMP4.bim + TEMP4.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile TEMP4
#   --make-bed
#   --out GD_EUR_AJ-updated
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996089.
# --a1-allele: 1211155 assignments made.
# 1211155 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated.bed + GD_EUR_AJ-updated.bim +
# GD_EUR_AJ-updated.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr1.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 1
#   --make-bed
#   --out GD_EUR_AJ-updated-chr1
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 97313 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995934.
# --a1-allele: 97313 assignments made.
# 97313 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr1.bed + GD_EUR_AJ-updated-chr1.bim +
# GD_EUR_AJ-updated-chr1.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr2.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 2
#   --make-bed
#   --out GD_EUR_AJ-updated-chr2
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 102501 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997019.
# --a1-allele: 102501 assignments made.
# 102501 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr2.bed + GD_EUR_AJ-updated-chr2.bim +
# GD_EUR_AJ-updated-chr2.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr3.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 3
#   --make-bed
#   --out GD_EUR_AJ-updated-chr3
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 86451 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997137.
# --a1-allele: 86451 assignments made.
# 86451 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr3.bed + GD_EUR_AJ-updated-chr3.bim +
# GD_EUR_AJ-updated-chr3.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr4.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 4
#   --make-bed
#   --out GD_EUR_AJ-updated-chr4
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 77860 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996861.
# --a1-allele: 77860 assignments made.
# 77860 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr4.bed + GD_EUR_AJ-updated-chr4.bim +
# GD_EUR_AJ-updated-chr4.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr5.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 5
#   --make-bed
#   --out GD_EUR_AJ-updated-chr5
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 70841 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997104.
# --a1-allele: 70841 assignments made.
# 70841 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr5.bed + GD_EUR_AJ-updated-chr5.bim +
# GD_EUR_AJ-updated-chr5.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr6.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 6
#   --make-bed
#   --out GD_EUR_AJ-updated-chr6
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 82906 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995656.
# --a1-allele: 82906 assignments made.
# 82906 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr6.bed + GD_EUR_AJ-updated-chr6.bim +
# GD_EUR_AJ-updated-chr6.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr7.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 7
#   --make-bed
#   --out GD_EUR_AJ-updated-chr7
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 66819 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995829.
# --a1-allele: 66819 assignments made.
# 66819 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr7.bed + GD_EUR_AJ-updated-chr7.bim +
# GD_EUR_AJ-updated-chr7.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr8.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 8
#   --make-bed
#   --out GD_EUR_AJ-updated-chr8
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 60921 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996601.
# --a1-allele: 60921 assignments made.
# 60921 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr8.bed + GD_EUR_AJ-updated-chr8.bim +
# GD_EUR_AJ-updated-chr8.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr9.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 9
#   --make-bed
#   --out GD_EUR_AJ-updated-chr9
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 52203 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995984.
# --a1-allele: 52203 assignments made.
# 52203 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr9.bed + GD_EUR_AJ-updated-chr9.bim +
# GD_EUR_AJ-updated-chr9.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr10.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 10
#   --make-bed
#   --out GD_EUR_AJ-updated-chr10
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 57793 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.9965.
# --a1-allele: 57793 assignments made.
# 57793 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr10.bed + GD_EUR_AJ-updated-chr10.bim +
# GD_EUR_AJ-updated-chr10.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr11.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 11
#   --make-bed
#   --out GD_EUR_AJ-updated-chr11
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 62496 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995752.
# --a1-allele: 62496 assignments made.
# 62496 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr11.bed + GD_EUR_AJ-updated-chr11.bim +
# GD_EUR_AJ-updated-chr11.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr12.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 12
#   --make-bed
#   --out GD_EUR_AJ-updated-chr12
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 57033 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996566.
# --a1-allele: 57033 assignments made.
# 57033 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr12.bed + GD_EUR_AJ-updated-chr12.bim +
# GD_EUR_AJ-updated-chr12.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr13.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 13
#   --make-bed
#   --out GD_EUR_AJ-updated-chr13
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 39991 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99744.
# --a1-allele: 39991 assignments made.
# 39991 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr13.bed + GD_EUR_AJ-updated-chr13.bim +
# GD_EUR_AJ-updated-chr13.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr14.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 14
#   --make-bed
#   --out GD_EUR_AJ-updated-chr14
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 38192 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996473.
# --a1-allele: 38192 assignments made.
# 38192 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr14.bed + GD_EUR_AJ-updated-chr14.bim +
# GD_EUR_AJ-updated-chr14.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr15.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 15
#   --make-bed
#   --out GD_EUR_AJ-updated-chr15
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 36839 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.996326.
# --a1-allele: 36839 assignments made.
# 36839 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr15.bed + GD_EUR_AJ-updated-chr15.bim +
# GD_EUR_AJ-updated-chr15.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr16.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 16
#   --make-bed
#   --out GD_EUR_AJ-updated-chr16
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 42195 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.994125.
# --a1-allele: 42195 assignments made.
# 42195 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr16.bed + GD_EUR_AJ-updated-chr16.bim +
# GD_EUR_AJ-updated-chr16.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr17.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 17
#   --make-bed
#   --out GD_EUR_AJ-updated-chr17
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 41355 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.993503.
# --a1-allele: 41355 assignments made.
# 41355 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr17.bed + GD_EUR_AJ-updated-chr17.bim +
# GD_EUR_AJ-updated-chr17.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr18.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 18
#   --make-bed
#   --out GD_EUR_AJ-updated-chr18
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 33251 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.997329.
# --a1-allele: 33251 assignments made.
# 33251 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr18.bed + GD_EUR_AJ-updated-chr18.bim +
# GD_EUR_AJ-updated-chr18.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr19.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 19
#   --make-bed
#   --out GD_EUR_AJ-updated-chr19
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 34222 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.991838.
# --a1-allele: 34222 assignments made.
# 34222 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr19.bed + GD_EUR_AJ-updated-chr19.bim +
# GD_EUR_AJ-updated-chr19.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr20.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 20
#   --make-bed
#   --out GD_EUR_AJ-updated-chr20
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 29776 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995412.
# --a1-allele: 29776 assignments made.
# 29776 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr20.bed + GD_EUR_AJ-updated-chr20.bim +
# GD_EUR_AJ-updated-chr20.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr21.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 21
#   --make-bed
#   --out GD_EUR_AJ-updated-chr21
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 17095 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.995707.
# --a1-allele: 17095 assignments made.
# 17095 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr21.bed + GD_EUR_AJ-updated-chr21.bim +
# GD_EUR_AJ-updated-chr21.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr22.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 22
#   --make-bed
#   --out GD_EUR_AJ-updated-chr22
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 18835 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.99321.
# --a1-allele: 18835 assignments made.
# 18835 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr22.bed + GD_EUR_AJ-updated-chr22.bim +
# GD_EUR_AJ-updated-chr22.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# PLINK v1.90b4.4 64-bit (21 May 2017)           www.cog-genomics.org/plink/1.9/
# (C) 2005-2017 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to GD_EUR_AJ-updated-chr23.log.
# Options in effect:
#   --a1-allele Force-Allele1-GD_EUR_AJ-HRC.txt
#   --bfile GD_EUR_AJ-updated
#   --chr 23
#   --make-bed
#   --out GD_EUR_AJ-updated-chr23
#
# 1547809 MB RAM detected; reserving 773904 MB for main workspace.
# 4267 out of 1211155 variants loaded from .bim file.
# 249 people (125 males, 124 females) loaded from .fam.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 249 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.994228.
# --a1-allele: 4267 assignments made.
# 4267 variants and 249 people pass filters and QC.
# Note: No phenotypes present.
# --make-bed to GD_EUR_AJ-updated-chr23.bed + GD_EUR_AJ-updated-chr23.bim +
# GD_EUR_AJ-updated-chr23.fam ... 101112131415161718192021222324252627282930313233343536373839404142434445464748495051525354555657585960616263646566676869707172737475767778798081828384858687888990919293949596979899done.
# Executing: plink --bfile GD_EUR_AJ-updated-chr1 --recode vcf --chr 1 --out EUR_AJ_chr1
# Executing: plink --bfile GD_EUR_AJ-updated-chr2 --recode vcf --chr 2 --out EUR_AJ_chr2
# Executing: plink --bfile GD_EUR_AJ-updated-chr3 --recode vcf --chr 3 --out EUR_AJ_chr3
# Executing: plink --bfile GD_EUR_AJ-updated-chr4 --recode vcf --chr 4 --out EUR_AJ_chr4
# Executing: plink --bfile GD_EUR_AJ-updated-chr5 --recode vcf --chr 5 --out EUR_AJ_chr5
# Executing: plink --bfile GD_EUR_AJ-updated-chr6 --recode vcf --chr 6 --out EUR_AJ_chr6
# Executing: plink --bfile GD_EUR_AJ-updated-chr7 --recode vcf --chr 7 --out EUR_AJ_chr7
# Executing: plink --bfile GD_EUR_AJ-updated-chr8 --recode vcf --chr 8 --out EUR_AJ_chr8
# Executing: plink --bfile GD_EUR_AJ-updated-chr9 --recode vcf --chr 9 --out EUR_AJ_chr9
# Executing: plink --bfile GD_EUR_AJ-updated-chr10 --recode vcf --chr 10 --out EUR_AJ_chr10
# Executing: plink --bfile GD_EUR_AJ-updated-chr11 --recode vcf --chr 11 --out EUR_AJ_chr11
# Executing: plink --bfile GD_EUR_AJ-updated-chr12 --recode vcf --chr 12 --out EUR_AJ_chr12
# Executing: plink --bfile GD_EUR_AJ-updated-chr13 --recode vcf --chr 13 --out EUR_AJ_chr13
# Executing: plink --bfile GD_EUR_AJ-updated-chr14 --recode vcf --chr 14 --out EUR_AJ_chr14
# Executing: plink --bfile GD_EUR_AJ-updated-chr15 --recode vcf --chr 15 --out EUR_AJ_chr15
# Executing: plink --bfile GD_EUR_AJ-updated-chr16 --recode vcf --chr 16 --out EUR_AJ_chr16
# Executing: plink --bfile GD_EUR_AJ-updated-chr17 --recode vcf --chr 17 --out EUR_AJ_chr17
# Executing: plink --bfile GD_EUR_AJ-updated-chr18 --recode vcf --chr 18 --out EUR_AJ_chr18
# Executing: plink --bfile GD_EUR_AJ-updated-chr19 --recode vcf --chr 19 --out EUR_AJ_chr19
# Executing: plink --bfile GD_EUR_AJ-updated-chr20 --recode vcf --chr 20 --out EUR_AJ_chr20
# Executing: plink --bfile GD_EUR_AJ-updated-chr21 --recode vcf --chr 21 --out EUR_AJ_chr21
# Executing: plink --bfile GD_EUR_AJ-updated-chr22 --recode vcf --chr 22 --out EUR_AJ_chr22
# Executing: plink --bfile GD_EUR_AJ-updated-chr23 --recode vcf --chr 23 --out EUR_AJ_chr23

# %%
label_outdir = f'{imputed_out_dir}/{label}'
impute_prep_outdir = f'{gd_path}/QC/{label}'
impute_prep_geno = f'{impute_prep_outdir}/{label}'
print(impute_prep_geno)
vcf_list = [f'{impute_prep_geno}_pre_impute_chr{str(i)}.vcf.gz' for i in range(1,24)]

job_json = submit_job(vcf_list, password=password, token=token)

job_id = job_json['id']

job_id_df = pd.DataFrame({'job_id': [job_id], 'label': [label], 'path': [geno]})
# job_id_df = job_id_df.append(job_id_df_tmp)

job_id_df.to_csv(f'{imputed_out_dir}/EUR_AJ_impute_job_ids.csv', index=False)
# Out:
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ
# ['/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr1.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr2.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr3.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr4.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr5.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr6.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr7.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr8.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr9.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr10.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr11.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr12.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr13.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr14.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr15.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr16.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr17.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr18.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr19.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr20.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr21.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr22.vcf.gz', '/data/CARD/PD/GP2/raw_genotypes/GD/QC/EUR_AJ/EUR_AJ_pre_impute_chr23.vcf.gz']
# job-20210830-171721-293 Your job was successfully added to the job queue.
# ***************************
# * * * * * * * * * * * * * *

# %%
imputed_out_dir = '/data/CARD/PD/GP2/genotypes/GD/imputed' 
# !cat {imputed_out_dir}/impute_job_ids.csv
# !cat {imputed_out_dir}/EUR_AJ_impute_job_ids.csv

impute_jobs1 = pd.read_csv(f'{imputed_out_dir}/EUR_AJ_impute_job_ids.csv')
impute_jobs2 = pd.read_csv(f'{imputed_out_dir}/impute_job_ids.csv')
impute_jobs2.drop(columns=['Unnamed: 0'], inplace=True)
impute_jobs = impute_jobs1.append(impute_jobs2)
impute_jobs
# Out:
#                     job_id   label  \
# 0  job-20210830-171721-293  EUR_AJ
# 0  job-20210830-160043-679     AMR
# 1  job-20210830-160045-801     EAS
#
#                                              path
# 0  /data/CARD/PD/GP2/genotypes/GD/clean/GD_EUR_AJ
# 0     /data/CARD/PD/GP2/genotypes/GD/clean/GD_AMR
# 1     /data/CARD/PD/GP2/genotypes/GD/clean/GD_EAS

# %%
from QC.imputation import *
import QC.config as config
token = config.api_key
password = 'imputer'


for i, job_id in enumerate(impute_jobs.job_id):
    impute_outpath = f'/data/CARD/PD/GP2/genotypes/GD/imputed/{impute_jobs.iloc[i].label}'
    print(impute_outpath)
    pull_imputed_data(impute_outpath, token, job_id, password)
# Out:
# /data/CARD/PD/GP2/genotypes/GD/imputed/EUR_AJ
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368819/152c0466a61a3ac69e897a34b7d8e74c325ddc025d4c2979bb6ca127fd7d09b0 | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368823/caae4e3fd2829aea028d0a9473b011d2b248b3a3154047e4f79f204e3bf7d58c | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368825/1ccfd61a561587e3f89e0f54fd7fbf55f5489e0b02f789dc686281a396c4997f | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368826/6862c7cc7a72c3b1c7c5bffe5e619850fea2dfe4c0c77568639cd37b21765b98 | bash
#
# Finished Pulling Imputed Data!
#
# /data/CARD/PD/GP2/genotypes/GD/imputed/AMR
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368672/8390fcda9b1b57f1cf40fe643af9f8c95d8fba440b67072ecfbf4e918531c19d | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368676/1d68b60f4de2087e156a6db2097edb1b486538b94c7393495cc661bb9b2732e0 | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368678/79c81c764eecef8a0c5bb9bf6f1920b5a2ca782e102a791ae5afb595cb10fa9b | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368679/99ad793761455777429ef98a5e18c7650d74bcf7643542da5efb786ed76f6a99 | bash
#
# Finished Pulling Imputed Data!
#
# /data/CARD/PD/GP2/genotypes/GD/imputed/EAS
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368693/d9c33890260c629889eba2c57115d6c31a4a14a09bfc65793a3fe410c46ec549 | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368697/e6533894e2902766fc39feddc231239ac3580f3e26072edded827629efc5b4bf | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368699/e70b801a0bcf45e754c8830d18190f2fe7da5e722a2774e4d35b58c7049aa395 | bash
# Curling output data with the following command: curl -sL https://imputation.biodatacatalyst.nhlbi.nih.gov/get/368700/2d5880860f51a6eb1e77be126ca06a88fe32588711f10409089b1d0cfac226b7 | bash
#
# Finished Pulling Imputed Data!

# %%
QC_metrics_path = f'{out_path}.QC.metrics.h5'

metrics_df = pd.read_hdf(QC_metrics_path, key='QC')
ancestry_counts_df = pd.read_hdf(QC_metrics_path, key='ancestry_counts')
pred_ancestry_labels = pd.read_hdf(QC_metrics_path, key='ancestry_labels')
conf_mat_df = pd.read_hdf(QC_metrics_path, key='confusion_matrix', index=True)
ref_pcs = pd.read_hdf(QC_metrics_path, key='ref_pcs')
projected_pcs = pd.read_hdf(QC_metrics_path, key='projected_pcs')
total_umap = pd.read_hdf(QC_metrics_path, key='total_umap')
ref_umap = pd.read_hdf(QC_metrics_path, key='ref_umap')
new_samples_umap = pd.read_hdf(QC_metrics_path, key='new_samples_umap')

# %%
# !ls /data/CARD/PD/GP2/genotypes/GD/clean/
# Out:
# GD_AAC.bed  GD_AJ.bed  GD_AMR.bed  GD_EAS.bed  GD_EUR.bed  GD.QC.metrics.h5
# GD_AAC.bim  GD_AJ.bim  GD_AMR.bim  GD_EAS.bim  GD_EUR.bim
# GD_AAC.fam  GD_AJ.fam  GD_AMR.fam  GD_EAS.fam  GD_EUR.fam
# GD_AAC.hh   GD_AJ.hh   GD_AMR.hh   GD_EAS.hh   GD_EUR.hh
# GD_AAC.log  GD_AJ.log  GD_AMR.log  GD_EAS.log  GD_EUR.log

# %%
# !cat {swarm_scripts_dir}/logs/swarm_21042872_0.e
# !cat /data/CARD/PD/GP2/raw_genotypes/GD/swarm_scripts/logs/swarm_21059707_0.e
# Out:
# Warning: 6883 het. haploid genotypes present (see
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_missing.hh ); many commands treat
# these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Warning: 4301 het. haploid genotypes present (see
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate.hh ); many commands treat
# these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Warning: 4301 het. haploid genotypes present (see
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_tmp1.hh ); many commands
# treat these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Warning: 4228 het. haploid genotypes present (see
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_tmp2.hh ); many commands
# treat these as missing.
# Warning: 4301 het. haploid genotypes present (see
# /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex.hh ); many commands treat
# these as missing.
# Warning: Nonmissing nonmale Y chromosome genotype(s) present; many commands
# treat these as missing.
# Warning: Impossible A1 allele assignment for variant rs2257182.
# Warning: Impossible A1 allele assignment for variant rs262680.
# Warning: Impossible A1 allele assignment for variant rs2483266.
# Warning: Impossible A1 allele assignment for variant rs4415513.
# Warning: Impossible A1 allele assignment for variant rs4364818.
# Warning: Impossible A1 allele assignment for variant rs6688969.
# Warning: Impossible A1 allele assignment for variant rs10909830.
# Warning: Impossible A1 allele assignment for variant rs10915421.
# Warning: Impossible A1 allele assignment for variant rs12132314.
# Warning: Impossible A1 allele assignment for variant rs10799145.
# Warning: Impossible A1 allele assignment for variant rs770705.
# Warning: Impossible A1 allele assignment for variant rs781571.
# Warning: Impossible A1 allele assignment for variant rs17089553.
# Warning: Impossible A1 allele assignment for variant rs6813806.
# Warning: Impossible A1 allele assignment for variant rs17090446.
# Warning: Impossible A1 allele assignment for variant rs12642037.
# Warning: Impossible A1 allele assignment for variant rs1000226.
# Warning: Impossible A1 allele assignment for variant rs11944965.
# Warning: Impossible A1 allele assignment for variant rs787361.
# Warning: Impossible A1 allele assignment for variant rs17592868.
# Warning: Impossible A1 allele assignment for variant rs12645716.
# Warning: Impossible A1 allele assignment for variant rs422140.
# Warning: Impossible A1 allele assignment for variant rs17002218.
# Warning: Impossible A1 allele assignment for variant rs4859756.
# Warning: Impossible A1 allele assignment for variant rs7656678.
# Warning: Impossible A1 allele assignment for variant rs17005457.
# Warning: Impossible A1 allele assignment for variant rs17353295.
# Warning: Impossible A1 allele assignment for variant rs6822001.
# Warning: Impossible A1 allele assignment for variant rs6825533.
# Warning: Impossible A1 allele assignment for variant rs2725225.
# Warning: Impossible A1 allele assignment for variant rs7660707.
# Warning: Impossible A1 allele assignment for variant rs17780881.
# Warning: Impossible A1 allele assignment for variant rs17015895.
# Warning: Impossible A1 allele assignment for variant rs17286290.
# Warning: Impossible A1 allele assignment for variant rs7659159.
# Warning: Impossible A1 allele assignment for variant rs12639623.
# Warning: Impossible A1 allele assignment for variant rs11097470.
# Warning: Impossible A1 allele assignment for variant rs2054159.
# Warning: Impossible A1 allele assignment for variant rs1514976.
# Warning: Impossible A1 allele assignment for variant rs10004753.
# Warning: Impossible A1 allele assignment for variant rs2178125.
# Warning: Impossible A1 allele assignment for variant rs1426730.
# ...
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /usr/local/Anaconda/envs/py3.7/lib/python3.7/site-packages/sklearn/svm/_base.py:986: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ.samples --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR.samples --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR.samples --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS.samples --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS.samples --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC.samples --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC
# Executing: gcta --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ --autosome --maf 0.05 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_total_grm_tmp
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_total_grm_tmp --grm-cutoff 0.125 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_unrelated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_unrelated_grm_tmp.grm.id --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_total_grm_tmp --grm-cutoff 0.95 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_duplicated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related --geno 0.01 --maf 0.05 --indep-pairwise 50 5 0.5 --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related --extract /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het_tmp.prune.in --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het_tmp2
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het_tmp2 --het --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het_tmp3
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het.outliers --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AJ_related_het
# Executing: gcta --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR --autosome --maf 0.05 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_total_grm_tmp
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_total_grm_tmp --grm-cutoff 0.125 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_unrelated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_unrelated_grm_tmp.grm.id --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_total_grm_tmp --grm-cutoff 0.95 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_duplicated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related --geno 0.01 --maf 0.05 --indep-pairwise 50 5 0.5 --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related --extract /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het_tmp.prune.in --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het_tmp2
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het_tmp2 --het --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het_tmp3
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het.outliers --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EUR_related_het
# Executing: gcta --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR --autosome --maf 0.05 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_total_grm_tmp
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_total_grm_tmp --grm-cutoff 0.125 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_unrelated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_unrelated_grm_tmp.grm.id --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_total_grm_tmp --grm-cutoff 0.95 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_duplicated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related --geno 0.01 --maf 0.05 --indep-pairwise 50 5 0.5 --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related --extract /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het_tmp.prune.in --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het_tmp2
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het_tmp2 --het --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het_tmp3
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het.outliers --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AMR_related_het
# Executing: gcta --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS --autosome --maf 0.05 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_total_grm_tmp
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_total_grm_tmp --grm-cutoff 0.125 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_unrelated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_unrelated_grm_tmp.grm.id --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_total_grm_tmp --grm-cutoff 0.95 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_duplicated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related --geno 0.01 --maf 0.05 --indep-pairwise 50 5 0.5 --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related --extract /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het_tmp.prune.in --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het_tmp2
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het_tmp2 --het --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het_tmp3
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het.outliers --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het
# Executing: gcta --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS --autosome --maf 0.05 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_total_grm_tmp
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_total_grm_tmp --grm-cutoff 0.125 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_unrelated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_unrelated_grm_tmp.grm.id --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_total_grm_tmp --grm-cutoff 0.95 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_duplicated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related --geno 0.01 --maf 0.05 --indep-pairwise 50 5 0.5 --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related --extract /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het_tmp.prune.in --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het_tmp2
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het_tmp2 --het --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het_tmp3
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het.outliers --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_EAS_related_het
# Executing: gcta --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC --autosome --maf 0.05 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_total_grm_tmp
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_total_grm_tmp --grm-cutoff 0.125 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_unrelated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC --keep /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_unrelated_grm_tmp.grm.id --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related
# Executing: gcta --grm /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_total_grm_tmp --grm-cutoff 0.95 --make-grm --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_duplicated_grm_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related --geno 0.01 --maf 0.05 --indep-pairwise 50 5 0.5 --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het_tmp
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related --extract /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het_tmp.prune.in --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het_tmp2
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het_tmp2 --het --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het_tmp3
# Executing: plink --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het.outliers --make-bed --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_AAC_related_het
# Traceback (most recent call last):
#   File "run_gd_pipeline.py", line 72, in <module>
#     steps2 = [het_dict, related_dict, variant_dict]
# NameError: name 'variant_dict' is not defined

# %%
# !cat /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het.log
# Out:
# PLINK v1.90b4.4 64-bit (21 May 2017)
# Options in effect:
#   --bfile /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related
#   --make-bed
#   --out /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het
#   --remove /data/CARD/PD/GP2/raw_genotypes/GD/QC/GD_callrate_sex_ancestry_SAS_related_het.outliers
#
# Hostname: cn3393
# Working directory: /gpfs/gsfs12/users/vitaled2/GenoTools/GP2_data_processing
# Start time: Fri Aug 13 15:22:17 2021
#
# Random number seed: 1628882537
# 257652 MB RAM detected; reserving 128826 MB for main workspace.
# 2004347 variants loaded from .bim file.
# 2 people (0 males, 2 females) loaded from .fam.
# Error: No people remaining after --remove.
#
# End time: Fri Aug 13 15:22:18 2021
